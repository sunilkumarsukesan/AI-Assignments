# %%
import matplotlib.pyplot as plt

# %%
x = [1, 2, 3, 4, 5]
y = [22, 66, 88, 33, 55]
#colors = ['red', 'blue', 'green', 'orange', 'purple']  # one color per point

colors = [10, 20, 30, 40, 50]

plt.scatter(x, y, c=colors, s=100, edgecolors='black', cmap = 'inferno')
plt.title("Scatter Plot with Multiple Colors")
plt.colorbar()
plt.xlabel("X values")
plt.ylabel("Y values")
plt.show()

# %%
# Generate random data for the histogram
data = [10,20,15,20,35,50,11,12,5, 8,10, 11,45,50,60, 23, 1]

# Plotting a basic histogram
plt.hist(data, bins=5, color='pink', edgecolor='black')

# Adding labels and title
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.title('Basic Histogram' )

plt.show()

# %%
# Data for the pie chart
labels = ['CTS' , 'TCS', 'Wipro' , 'TestLeaf']
sizes = [35, 25,25, 15] # Proportions of each category

# Create the pie chart
plt.pie(sizes, labels=labels, autopct='%1.0f%%', startangle=90 , frame = True, shadow=True)

# Add a title (optional)
plt.title('Participant Distribution' )

# Ensure the pie chart is drawn as a circle
plt.axis('equal')
# Out:
# (np.float64(-1.0999995661401356),
#  np.float64(1.0999995996936662),
#  np.float64(-1.0999920212726433),
#  np.float64(1.0999996200606021))

# %%
import numpy as np

#These numbers are sampled from a "standard normal" (or Gaussian) distribution.
data1 = np.random.randn(1000) + 2

# Create 2x2 grid of subplots
fig, axes = plt.subplots(2, 2, figsize=(10, 8))

# 'bar' histtype
axes[0, 0].hist(data1, bins=30, histtype='bar', color='skyblue', edgecolor='black')
axes[0, 0].set_title('histtype="bar"')

# 'barstacked' histtype with multiple datasets
axes[0, 1].hist([data1, data2], bins=30, histtype='barstacked', color=['lightcoral', 'lightgreen' ], edgecolor='blue')
axes[0, 1].set_title('histtype="barstacked"')

# 'step' histtype
axes[1, 0].hist(data1, bins=30, histtype='step', color='purple', linewidth=2)
axes[1, 0].set_title('histtype="step"')

# 'stepfilled' histtype
axes[1, 1].hist(data1, bins=30, histtype='stepfilled', color='orange', alpha=0.7, edgecolor='black')
axes[1, 1].set_title('histtype="stepfilled"')

plt.tight_layout()
plt.show()

# %%
counts, bins, patches = plt.hist(data, bins=10)
print(data)
print(counts)
print(bins)
print(patches)
for i, patch in enumerate(patches):
    plt.setp(patch, 'facecolor', plt.cm.viridis(i/len(patches)))
# Out:
# [10, 20, 15, 20, 35, 50, 11, 12, 5, 8, 10, 11, 45, 50, 60, 23, 1]
# [2. 6. 1. 3. 0. 1. 0. 1. 2. 1.]
# [ 1.   6.9 12.8 18.7 24.6 30.5 36.4 42.3 48.2 54.1 60. ]
# <BarContainer object of 10 artists>
